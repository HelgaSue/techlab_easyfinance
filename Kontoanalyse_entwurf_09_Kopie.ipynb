# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# RUN THIS COMMAND ONLY IF YOU USE GOOGLE COLAB.
# %cd drive/MyDrive/TechLabs/PROJEKT/Kontoanalyse_/
# Out:
# /content/drive/MyDrive/TechLabs/PROJEKT/Kontoanalyse_

# %%
# This is the convention used to import Pandas.
import pandas as pd
# OTHER LIBRARIES.
import numpy as np

# %%
# These options help us to inspect our data more easily.
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# %%
# These commands load the same survey data Corey is using in his video.
df = pd.read_csv("Kontoauszug-fiktiv3.csv")

# %%
df.head(100)
# Out:
#         Valuta   Buchungsart                       Buchung_Verwendungszweck  \
# 0   2019-11-01   Lastschrift                           IKANO Bank AB (publ)
# 1   2019-11-01   Lastschrift                     CONSORS FINANZ BNP PARIBAS
# 2   2019-11-01   Lastschrift                                  VISA PSK 5230
# 3   2019-11-01   Lastschrift                               VISA HOFER DANKT
# 4   2019-11-04   Lastschrift                         VISA DM DROGERIE MARKT
# 5   2019-11-04   Lastschrift                      VISA TAPPE GMBH OBERNDORF
# 6   2019-11-04   Lastschrift                       VISA APOTHEKE ZUR MARIAH
# 7   2019-11-04   Lastschrift  Bargeldauszahlung VISA Card POSTBANK MARKTLER
# 8   2019-11-05   Lastschrift                    VISA AMZNPRIME DE*SG1C45775
# 9   2019-11-05   Lastschrift                     VISA PRIME VIDEO*6Y2ZO2L05
# 10  2019-11-05   Lastschrift                               VISA HOFER DANKT
# 11  2019-11-05   Lastschrift                                 VISA HM AT0003
# 12  2019-11-05   Lastschrift                      VISA ALDI SUED SAGT DANKE
# 13  2019-11-05   Lastschrift                     VISA PRIME VIDEO*JM3DR06W5
# 14  2019-11-05   Lastschrift                      VISA MUELLER GMBH & CO.KG
# 15  2019-11-05   Lastschrift                      VISA MUELLER GMBH & CO.KG
# 16  2019-11-06   Lastschrift                         VISA DM DROGERIE MARKT
# 17  2019-11-06   Lastschrift                         VISA DM DROGERIE MARKT
# 18  2019-11-06     Abbuchung                    First Data Deutschland GmbH
# 19  2019-11-07   Lastschrift                Vodafone Kabel Deutschland GmbH
# 20  2019-11-08   Lastschrift                                 VISA INNTALHOF
# 21  2019-11-08   Lastschrift                         VISA DM-DROGERIE MARKT
# 22  2019-11-08   Lastschrift                        VISA H&M PASSAU 1DE0301
# 23  2019-11-08   Lastschrift                    VISA NORTHLAND OUTDOOR SHOP
# 24  2019-11-08   Lastschrift                              VISA HOTEL KOENIG
# 25  2019-11-08  Ueberweisung                             Haus der Begegnung
# 26  2019-11-30    Gutschrift                                         Gehalt
# 27  2019-12-01   Lastschrift                               VISA HOFER DANKT
# 28  2019-12-01   Lastschrift                         VISA DM DROGERIE MARKT
# 29  2019-12-01   Lastschrift                                 VISA AMAZON EU
# 30  2019-12-01   Lastschrift                               VISA NETFLIX.COM
# 31  2019-12-01   Lastschrift                                   VISA Spotify
# 32  2019-12-01   Lastschrift                              VISA AMAZON PRIME
# 33  2019-12-01   Lastschrift                               VISA PRIME VIDEO
# 34  2019-12-01   Lastschrift                                 VISA ALDI SUED
# 35  2019-12-01   Lastschrift                                  VISA VODAFONE
# 36  2019-12-01   Lastschrift                                 VISA INNTALHOF
# 37  2019-12-01   Lastschrift                         VISA DM-DROGERIE MARKT
# 38  2019-12-01   Lastschrift                        VISA H&M PASSAU 1DE0301
# 39  2019-12-01   Lastschrift                    VISA NORTHLAND OUTDOOR SHOP
# 40  2019-12-01   Lastschrift                              VISA HOTEL KOENIG
# 41  2019-12-01  Ueberweisung                             Haus der Begegnung
# 42  2019-12-31    Gutschrift                                         Gehalt
# 43  2020-01-01   Lastschrift                               VISA HOFER DANKT
# 44  2020-01-01   Lastschrift                         VISA DM DROGERIE MARKT
# 45  2020-01-01   Lastschrift                                 VISA AMAZON EU
# 46  2020-01-01   Lastschrift                               VISA NETFLIX.COM
# 47  2020-01-01   Lastschrift                                   VISA Spotify
# 48  2020-01-01   Lastschrift                              VISA AMAZON PRIME
# 49  2020-01-01   Lastschrift                               VISA PRIME VIDEO
# 50  2020-01-01   Lastschrift                                 VISA ALDI SUED
# 51  2020-01-01   Lastschrift                                  VISA VODAFONE
# 52  2020-01-01   Lastschrift                                 VISA INNTALHOF
# 53  2020-01-01   Lastschrift                         VISA DM-DROGERIE MARKT
# 54  2020-01-01   Lastschrift                        VISA H&M PASSAU 1DE0301
# 55  2020-01-01   Lastschrift                    VISA NORTHLAND OUTDOOR SHOP
# 56  2020-01-01   Lastschrift                              VISA HOTEL KOENIG
# 57  2020-01-01  Ueberweisung                             Haus der Begegnung
# 58  2020-01-31    Gutschrift                                         Gehalt
# 59  2020-02-01   Lastschrift                               VISA HOFER DANKT
# 60  2020-02-01   Lastschrift                         VISA DM DROGERIE MARKT
# 61  2020-02-01   Lastschrift                                 VISA AMAZON EU
# 62  2020-02-01   Lastschrift                               VISA NETFLIX.COM
# 63  2020-02-01   Lastschrift                                   VISA Spotify
# 64  2020-02-01   Lastschrift                              VISA AMAZON PRIME
# 65  2020-02-01   Lastschrift                               VISA PRIME VIDEO
# 66  2020-02-01   Lastschrift                                 VISA ALDI SUED
# 67  2020-02-01   Lastschrift                                  VISA VODAFONE
# 68  2020-02-01   Lastschrift                                 VISA INNTALHOF
# 69  2020-02-01   Lastschrift                         VISA DM-DROGERIE MARKT
# 70  2020-02-01   Lastschrift                        VISA H&M PASSAU 1DE0301
# 71  2020-02-01   Lastschrift                    VISA NORTHLAND OUTDOOR SHOP
# 72  2020-02-01   Lastschrift                              VISA HOTEL KOENIG
# 73  2020-02-01  Ueberweisung                             Haus der Begegnung
# 74  2020-02-29    Gutschrift                                         Gehalt
# 75  2020-03-01   Lastschrift                               VISA HOFER DANKT
# 76  2020-03-01   Lastschrift                         VISA DM DROGERIE MARKT
# 77  2020-03-01   Lastschrift                                 VISA AMAZON EU
# 78  2020-03-01   Lastschrift                               VISA NETFLIX.COM
# 79  2020-03-01   Lastschrift                                   VISA Spotify
# 80  2020-03-01   Lastschrift                              VISA AMAZON PRIME
# 81  2020-03-01   Lastschrift                               VISA PRIME VIDEO
# 82  2020-03-01   Lastschrift                                 VISA ALDI SUED
# 83  2020-03-01   Lastschrift                                  VISA VODAFONE
# 84  2020-03-01   Lastschrift                                 VISA INNTALHOF
# 85  2020-03-01   Lastschrift                         VISA DM-DROGERIE MARKT
# 86  2020-03-01   Lastschrift                        VISA H&M PASSAU 1DE0301
# 87  2020-03-01   Lastschrift                    VISA NORTHLAND OUTDOOR SHOP
# 88  2020-03-01   Lastschrift                              VISA HOTEL KOENIG
# 89  2020-03-01  Ueberweisung                             Haus der Begegnung
# 90  2020-03-31    Gutschrift                                         Gehalt
#
#     Betrag_EUR
# 0       -83.34
# 1      -123.64
# 2        -6.01
# 3       -30.53
# 4       -42.90
# 5       -34.80
# 6       -65.50
# 7      -110.00
# 8        -7.99
# 9        -4.99
# 10      -40.50
# 11      -10.98
# 12      -27.30
# 13       -3.99
# 14      -14.03
# 15      -19.98
# 16      -20.00
# 17      -15.25
# 18     -180.17
# 19      -34.99
# 20      -78.00
# 21      -12.25
# 22      -25.11
# 23      -44.95
# 24     -103.00
# 25     -154.00
# 26     3000.00
# 27      -35.00
# 28      -50.00
# 29      -15.99
# 30      -11.99
# 31       -9.99
# 32       -7.99
# 33       -5.99
# 34      -30.00
# 35      -34.99
# 36      -78.00
# 37      -12.25
# 38      -25.11
# 39      -44.95
# 40     -103.00
# 41     -154.00
# 42     3000.00
# 43      -35.00
# 44      -50.00
# 45      -15.99
# 46      -11.99
# 47       -9.99
# 48       -7.99
# 49       -5.99
# 50      -30.00
# 51      -34.99
# 52      -78.00
# 53      -12.25
# 54      -25.11
# 55      -44.95
# 56     -103.00
# 57     -154.00
# 58     3000.00
# 59      -35.00
# 60      -50.00
# 61      -15.99
# 62      -11.99
# 63       -9.99
# 64       -7.99
# 65       -5.99
# 66      -30.00
# 67      -34.99
# 68      -78.00
# 69      -12.25
# 70      -25.11
# 71      -44.95
# 72     -103.00
# 73     -154.00
# 74     3000.00
# 75      -35.00
# 76      -50.00
# 77      -15.99
# 78      -11.99
# 79       -9.99
# 80       -7.99
# 81       -5.99
# 82      -30.00
# 83      -34.99
# 84      -78.00
# 85      -12.25
# 86      -25.11
# 87      -44.95
# 88     -103.00
# 89     -154.00
# 90     3000.00

# %%
import csv
from datetime import datetime
import pandas as pd

# Funktion zum Laden von Transaktionen aus einer CSV-Datei
def load_transactions(csv_file):
    with open(csv_file, newline='', encoding='ISO-8859-1') as file:
        reader = csv.DictReader(file)
        transactions = list(reader)
    return transactions


# Funktion zur Auswahl aus einer Liste von Optionen
def choose_from_list(prompt, options):
    while True:
      #zeigt eine Liste von Optionen an, die der Benutzer auswählen kann
        print(prompt)
        for i, option in enumerate(options, start=1): #nummeriert die liste
            print(f"{i}. {option}")

        #Benutzer gibt die Nummer der Auswahl ein, und die Funktion gibt die ausgewählte Option zurück.
        choice = input("Gib die Nummer der Auswahl ein: ")
        try:
            index = int(choice) - 1
            if 0 <= index < len(options):
                return options[index]
            else:
                print("Ungültige Auswahl. Versuche es erneut.")
        except ValueError:
            print("Ungültige Eingabe. Bitte gib eine Zahl ein.")


# Hauptfunktion zur Filterung und Summierung von Transaktionen. Sie interagiert mit dem Benutzer,
# um eine CSV-Datei zu laden, einen Zeitraum festzulegen, Buchungsarten und Verwendungszwecke auszuwählen,
# Transaktionen zu filtern, Einnahmen und Ausgaben zu berechnen und schließlich eine Zusammenfassung anzuzeigen.
def filter_and_sum_transactions():
  #Überspringe die Initialisierung von Variablen
    csv_file = None
    transactions = None
    start_date = None
    end_date = None

    while True:
        # Benutzereingabe für die CSV-Datei
        if csv_file is None or input("Möchtest du eine neue bzw. andere CSV-Datei laden (aus dem gleichen Dateipfad)? (ja/nein): ").lower() == 'ja':
            csv_file = input("Gib den CSV-Dateinamen ein: ")
            transactions = load_transactions(csv_file)

            # Zeige DataFrame-Ausschnitt
            display_part_dataframe(transactions)

        # Benutzereingabe für den Zeitraum
        if start_date is None or end_date is None or input("Möchtest du einen neuen bzw. anderen Zeitraum festlegen? (ja/nein): ").lower() == 'ja':
            start_date_str = input("Gib das Startdatum im Format JJJJ-MM-TT ein: ")
            end_date_str = input("Gib das Enddatum im Format JJJJ-MM-TT ein: ")

            try:
                # Konvertiere die Benutzereingabe in datetime-Objekte
                start_date = datetime.strptime(start_date_str, '%Y-%m-%d')
                end_date = datetime.strptime(end_date_str, '%Y-%m-%d')
            except ValueError:
                print("Ungültiges Datumsformat. Verwende das Format JJJJ-MM-TT.")
                continue

        # Erstelle Auswahlliste für Buchungsart und lass den Benutzer auswählen
        available_transaction_types = list(get_unique_values_in_range(transactions, 'Transaktionsart', start_date, end_date))
        transaction_type = choose_from_list("Gib die Transaktionsart ein:", available_transaction_types)

        # Erstelle Auswahlliste für Verwendungszweck basierend auf der ausgewählten Transaktionsart
        available_purposes = list(get_unique_values_in_range(transactions, 'Verwendungszweck', start_date, end_date, 'Transaktionsart', transaction_type))

        # Liste die Verwendungszwecke auf inkl. Nummerierung
        print(f"Verwendungszwecke für die Buchungsart '{transaction_type}':")
        for i, purpose in enumerate(available_purposes, start=1):
            print(f"{i}. {purpose}")

        # Frage nach Zusammenführung
        merge_purposes = input("Möchtest du Verwendungszwecke zusammenführen? (ja/nein): ").lower() == 'ja'

        # Falls der Benutzer Verwendungszwecke zusammenführen möchte
        if merge_purposes:
            while True:
                # Lasse den Benutzer die Nummern der Verwendungszwecke eingeben
                purpose_indices_str = input("Gib die Nummern der Verwendungszwecke (durch Komma getrennt) ein: ")
                purpose_indices = purpose_indices_str.split(',')

                try:
                    # Umwandlung Benutzereingabe in eine Liste von Indexen
                    selected_purposes = [available_purposes[int(index) - 1] for index in purpose_indices]
                    break
                except (ValueError, IndexError):
                    print("Ungültige Eingabe. Bitte gib die Nummern erneut ein.")

            # Filtere Transaktionen nach dem angegebenen Zeitraum, Transaktionsart und ausgewählten Verwendungszwecken
            filtered_transactions = [t for t in transactions if (
                start_date is None or start_date <= datetime.strptime(t['Buchungsdatum'], '%Y-%m-%d') <= end_date
                and t['Transaktionsart'] == transaction_type
                and t['Verwendungszweck'].lower() in [purpose.lower() for purpose in selected_purposes]
            )]
        else:
            # Benutzereingabe von die Nummer des Verwendungszwecks
            while True:
                purpose_index_str = input("Gib die Nummer des Verwendungszwecks ein (leer lassen, wenn nicht relevant): ")
                if purpose_index_str == '':
                    purpose = ''
                    break

                try:
                    # Umwandlung der Benutzereingabe in den Index
                    purpose_index = int(purpose_index_str) - 1
                    purpose = available_purposes[purpose_index]
                    break
                except (ValueError, IndexError):
                    print("Ungültige Eingabe. Bitte gib die Nummer erneut ein.")

            # Filtere Transaktionen nach dem angegebenen Zeitraum, Buchungsart und ausgewähltem Verwendungszweck
            filtered_transactions = [t for t in transactions if (
                start_date is None or start_date <= datetime.strptime(t['Buchungsdatum'], '%Y-%m-%d') <= end_date
                and t['Transaktionsart'] == transaction_type
                and (purpose == '' or t['Verwendungszweck'].lower() == purpose.lower())
            )]

        # Initialisiere Variablen für Einnahmen, Ausgaben und Gesamtsumme
        income = 0
        expense = 0

        # Iteriere durch die gefilterten Transaktionen und aktualisiere Einnahmen und Ausgaben
        for transaction in filtered_transactions:
            amount = float(transaction['Betrag (EUR)'])
            if amount >= 0:
                income += amount
            else:
                expense += abs(amount)

        # Berechne die Gesamtsumme
        total = income - expense

        # Erstellung eines DataFrame für die Ergebnisse
        result_df = pd.DataFrame({
            'Buchungsdatum': [t['Buchungsdatum'] for t in filtered_transactions],
            'Transaktionsart': [t['Transaktionsart'] for t in filtered_transactions],
            'Verwendungszweck': [t['Verwendungszweck'] for t in filtered_transactions],
            'Betrag (EUR)': [float(t['Betrag (EUR)']) for t in filtered_transactions]
        })

        # Anzeige das Ergebnis DataFrames
        print("\nErgebnis DataFrame:")
        print(result_df)

        # Anzeige der Zusammenfassung
        print("\nZusammenfassung:")
        print(f"Transaktionen im Zeitraum: {start_date_str} bis {end_date_str}")
        print(f"Transaktionsart: {transaction_type}")
        print(f"ausgewählte Verwendungszweck(e): {', '.join(selected_purposes) if merge_purposes else purpose}")
        print(f"Einnahmen: {income:.2f} EUR")
        print(f"Ausgaben: {expense:.2f} EUR")
        print(f"Gesamt: {total:.2f} EUR")

        # Frage nach weiterer Analyse
        another_analysis = input("Möchtest du eine weitere Analyse durchführen? (ja/nein): ").lower()

        # Wenn der Benutzer keine weitere Analyse durchführen möchte, beende das Programm
        if another_analysis != 'ja':
            print("Das Programm wird beendet. Auf Wiedersehen!")
            break

# Funktion erstellt einen Teil-DataFrame (part_df) aus den übergebenen Daten und zeigt ihn an.
def display_part_dataframe(data):
    # Erstelle einen DataFrame-Ausschnitt
    part_df = pd.DataFrame(data)

    # Zeige das DataFrame an
    print("\nDataFrame Ausschnitt:")
    print(part_df)

# Funktion extrahiert eindeutige Werte für einen bestimmten Schlüssel (key) innerhalb eines Zeitraums (definiert durch start_date und end_date).
# Optional kann sie auch nach einem zusätzlichen Schlüssel-Wert-Paar (filter_key und filter_value) filtern.
def get_unique_values_in_range(data, key, start_date, end_date, filter_key=None, filter_value=None):
    if filter_key and filter_value is not None:
        return set(item[key] for item in data if start_date <= datetime.strptime(item['Buchungsdatum'], '%Y-%m-%d') <= end_date and item[filter_key] == filter_value)
    else:
        return set(item[key] for item in data if start_date <= datetime.strptime(item['Buchungsdatum'], '%Y-%m-%d') <= end_date)

# Hauptfunktion
# Eingabeaufforderung: Benutzereingabe für Zeitraum, Transaktionsart und Verwendungszweck
filter_and_sum_transactions()
# Out:
# Gib den CSV-Dateinamen ein: Kontoauszug-fiktiv3.csv
#
# DataFrame Ausschnitt:
#    Buchungsdatum Transaktionsart             Verwendungszweck Betrag (EUR)
# 0     2019-11-01     Lastschrift         IKANO Bank AB (publ)       -83.34
# 1     2019-11-01     Lastschrift   CONSORS FINANZ BNP PARIBAS      -123.64
# 2     2019-11-01     Lastschrift                VISA PSK 5230        -6.01
# 3     2019-11-01     Lastschrift             VISA HOFER DANKT       -30.53
# 4     2019-11-04     Lastschrift       VISA DM DROGERIE MARKT       -42.90
# ..           ...             ...                          ...          ...
# 86    2020-03-01     Lastschrift      VISA H&M PASSAU 1DE0301       -25.11
# 87    2020-03-01     Lastschrift  VISA NORTHLAND OUTDOOR SHOP       -44.95
# 88    2020-03-01     Lastschrift            VISA HOTEL KOENIG      -103.00
# 89    2020-03-01    Ueberweisung           Haus der Begegnung      -154.00
# 90    2020-03-31      Gutschrift                       Gehalt      3000.00
#
# [91 rows x 4 columns]
# Gib das Startdatum im Format JJJJ-MM-TT ein: 2019-11-01
# Gib das Enddatum im Format JJJJ-MM-TT ein: 2019-11-30
# Gib die Transaktionsart ein:
# 1. Lastschrift
# 2. Abbuchung
# 3. Gutschrift
# 4. Ueberweisung
# Gib die Nummer der Auswahl ein: 1
# Verwendungszwecke für die Buchungsart 'Lastschrift':
# 1. VISA APOTHEKE ZUR MARIAH
# 2. VISA TAPPE GMBH OBERNDORF
# 3. VISA DM-DROGERIE MARKT
# 4. VISA HM AT0003
# 5. VISA HOTEL KOENIG
# 6. Bargeldauszahlung VISA Card POSTBANK MARKTLER
# 7. VISA PRIME VIDEO*6Y2ZO2L05
# 8. VISA HOFER DANKT
# 9. VISA AMZNPRIME DE*SG1C45775
# 10. IKANO Bank AB (publ)
# 11. VISA H&M PASSAU 1DE0301
# 12. VISA DM DROGERIE MARKT
# 13. VISA MUELLER GMBH & CO.KG
# 14. VISA PSK 5230
# 15. VISA ALDI SUED SAGT DANKE
# 16. CONSORS FINANZ BNP PARIBAS
# 17. VISA PRIME VIDEO*JM3DR06W5
# 18. VISA NORTHLAND OUTDOOR SHOP
# 19. Vodafone Kabel Deutschland GmbH
# 20. VISA INNTALHOF
# Möchtest du Verwendungszwecke zusammenführen? (ja/nein): ja
# Gib die Nummern der Verwendungszwecke (durch Komma getrennt) ein: 7,9,17
#
# Ergebnis DataFrame:
#   Buchungsdatum Transaktionsart             Verwendungszweck  Betrag (EUR)
# 0    2019-11-05     Lastschrift  VISA AMZNPRIME DE*SG1C45775         -7.99
# 1    2019-11-05     Lastschrift   VISA PRIME VIDEO*6Y2ZO2L05         -4.99
# 2    2019-11-05     Lastschrift   VISA PRIME VIDEO*JM3DR06W5         -3.99
#
# Zusammenfassung:
# Transaktionen im Zeitraum: 2019-11-01 bis 2019-11-30
# Transaktionsart: Lastschrift
# ausgewählte Verwendungszweck(e): VISA PRIME VIDEO*6Y2ZO2L05, VISA AMZNPRIME DE*SG1C45775, VISA PRIME VIDEO*JM3DR06W5
# Einnahmen: 0.00 EUR
# Ausgaben: 16.97 EUR
# Gesamt: -16.97 EUR
# Möchtest du eine weitere Analyse durchführen? (ja/nein): ja
# Möchtest du eine neue bzw. andere CSV-Datei laden (aus dem gleichen Dateipfad)? (ja/nein): ja
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-732da9ff3ff2> in <cell line: 186>()
#     184 # Hauptfunktion
#     185 # Eingabeaufforderung: Benutzereingabe für Zeitraum, Transaktionsart und Verwendungszweck
# --> 186 filter_and_sum_transactions()
#
# <ipython-input-8-732da9ff3ff2> in filter_and_sum_transactions()
#      44         # Benutzereingabe für die CSV-Datei
#      45         if csv_file is None or input("Möchtest du eine neue bzw. andere CSV-Datei laden (aus dem gleichen Dateipfad)? (ja/nein): ").lower() == 'ja':
# ---> 46             csv_file = input("Gib den CSV-Dateinamen ein: ")
#      47             transactions = load_transactions(csv_file)
#      48
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
